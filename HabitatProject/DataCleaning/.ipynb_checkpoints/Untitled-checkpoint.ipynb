# %%
import pandas as pd
import folium

# Initialize map, centered on Edmonton, Canada
lynx_map = folium.Map(location=[53.5559564, -113.774813],
                        zoom_start=3,
                        tiles="CartoDB dark_matter")

# Import coordinate data for leopardus pardalis
df = pd.read_csv("test.csv")

# Add points to map
for index, row in df.iterrows():
    lon, lat, uuid = row["longitude"], row["latitude"], row["uuid"]
    point = [lat, lon]
    marker_color = "#0A8A9F"

    # Initialize marker and add to the map
    folium.CircleMarker(
        location=point, 
        color = marker_color, 
        fill=True,
        fill_color = marker_color,
        radius = 1
    ).add_to(lynx_map)
    
lynx_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import random

mapa = folium.Map(location = [45.6, -73.5], tiles = 'cartodbpositron' )

for x in range(3000):
    lat = random.uniform(45.4, 45.8)
    lon = random.uniform(-73.3, -73.9)
    folium.CircleMarker(location = [lat, lon], radius = 1).add_to(mapa)
    
mapa
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-d589d4dfbd7b> in <module>()
#      17     folium.CircleMarker(location = [lat, lon], radius = 1).add_to(mapa)
#      18
# ---> 19 inline_map(mapa)
#
# <ipython-input-13-d589d4dfbd7b> in inline_map(m, width, height)
#       3 def inline_map(m, width=650, height=500):
#       4     """Takes a folium instance and embed HTML."""
# ----> 5     m._build_map()
#       6     srcdoc = m.HTML.replace('"', '&quot;')
#       7     embed = HTML('<iframe srcdoc="{}" '
#
# AttributeError: 'Map' object has no attribute '_build_map'
